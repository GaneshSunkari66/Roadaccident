# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

# %%
# Get Dataset File Path
# path = os.path.abspath("")
# Alternatively
path = os.getcwd()
file = path + "\RTA Dataset.csv"
file
# Out:
# 'C:\\Users\\Amulya\\dap project\\RTA Dataset.csv'

# %%
# Load Cars Dataset
df = pd.read_csv(file)
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### Size of the Data

# %%
# Get Size of Dataset (Rows and Columns)
df.shape
# Out:
# (12316, 32)

# %% [markdown]
# ## Total Columns

# %%
# Get Information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %% [markdown]
# ## Check for Null Values

# %%
# To find the total no.of rows which are missing value in a column
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %% [markdown]
# ## Head and Tail

# %%
# Get Top 5 Records
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
# Get Last 5 Records
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %% [markdown]
# ## Numerical  columns

# %%
data_types = df.dtypes

# Separate numerical and categorical columns
numerical_columns = data_types[data_types != 'object'].index.tolist()
#categorical_columns = data_types[data_types == 'object'].index.tolist()

print("Numerical columns:", numerical_columns)
#print("\nCategorical columns:", categorical_columns)
# Out:
# Numerical columns: ['Number_of_vehicles_involved', 'Number_of_casualties']

# %%
# Get information about numerical columns
numerical_info = df.describe()

# Get information about categorical columns
categorical_info = {}
for column in df.select_dtypes(include=['object']):
    categorical_info[column] = df[column].value_counts()

# Print information about numerical columns
print("Numerical column information:")
print(numerical_info)

# Print information about categorical columns
print("\nCategorical column information:")
for column, info in categorical_info.items():
    print(f"\nColumn: {column}")
    print(info)
# Out:
# Numerical column information:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000
#
# Categorical column information:
#
# Column: Time
# Time
# 15:30:00    120
# 17:10:00    110
# 18:30:00    103
# 11:30:00     99
# 17:00:00     98
#            ...
# 19:04:00      1
# 20:36:00      1
# 22:54:00      1
# 21:03:00      1
# 2:47:00       1
# Name: count, Length: 1074, dtype: int64
#
# Column: Day_of_week
# Day_of_week
# Friday       2041
# Thursday     1851
# Wednesday    1840
# Tuesday      1770
# Monday       1681
# ...

# %% [markdown]
# ## Plots

# %%
df1 = df[['Type_of_vehicle','Driving_experience','Type_of_collision','Number_of_casualties','Vehicle_movement','Number_of_vehicles_involved','Casualty_severity','Accident_severity']]
df1
# Create subplots for the histograms
plt.figure(figsize=(12, 18))
for i, var in enumerate(df1, 1):
 plt.subplot(6, 2, i)
 sns.histplot(df[var], bins=20, kde=True)
 plt.title(f'Histogram of {var}')
 plt.xlabel(var)
 plt.ylabel('Overall')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Categorical columns

# %%
data_types = df.dtypes

# Separate numerical and categorical columns
#numerical_columns = data_types[data_types != 'object'].index.tolist()
categorical_columns = data_types[data_types == 'object'].index.tolist()

#print("Numerical columns:", numerical_columns)
print("\nCategorical columns:", categorical_columns)
# Out:
# Categorical columns: ['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver', 'Educational_level', 'Vehicle_driver_relation', 'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle', 'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction', 'Road_surface_type', 'Road_surface_conditions', 'Light_conditions', 'Weather_conditions', 'Type_of_collision', 'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity', 'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement', 'Cause_of_accident', 'Accident_severity']

# %% [markdown]
# ## Bar Plot

# %%
#df['Geography'] contains the 'Geography' feature with values 'France', 'Spain', and 'Germany'

# Count the occurrences of each category
geography_counts = df['Educational_level'].value_counts()

# Create bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=geography_counts.index, y=geography_counts.values)
plt.title('Knowledge of Vehciles')
plt.xlabel('Educational_level')
plt.ylabel('Count')
plt.show()

# %%
# Count the occurrences of each category
CardType_counts = df['Driving_experience'].value_counts()

# Create bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=CardType_counts.index, y=CardType_counts.values)
plt.title('Experience of Drivers')
plt.xlabel('Driving_experience')
plt.ylabel('Count')
plt.show()

# %%
# Count the occurrences of each category
Road_counts = df['Road_surface_conditions'].value_counts()

# Create bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=Road_counts.index, y=Road_counts.values)
plt.title('Type of Roads')
plt.xlabel('Road_surface_conditions')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
# Count the occurrences of each category
geography_counts = df['Educational_level'].value_counts()

# Create pie chart
plt.figure(figsize=(8, 6))
plt.pie(geography_counts, labels=geography_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Knowledge of Driving')
plt.axis('equal')  
# Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
# Count the occurrences of each category
CardType_counts = df['Driving_experience'].value_counts()

# Create pie chart
plt.figure(figsize=(8, 6))
plt.pie(CardType_counts, labels=CardType_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Experience of Drivers')
plt.axis('equal')  
# Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
# Count the occurrences of each category
Gender_counts = df['Road_surface_conditions'].value_counts()

# Create pie chart
plt.figure(figsize=(8, 6))
plt.pie(Gender_counts, labels=Gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Types of Roads')
plt.axis('equal')  
# Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# ## Count Plot

# %%
# Countplot of a categorical variable
plt.figure(figsize=(8, 6))
# Get the count of each category and sort them in ascending order
order = df['Educational_level'].value_counts().index
sns.countplot(x=df['Educational_level'], palette="Set1", order=order)
plt.title('')
plt.xlabel('Educational_level')
plt.ylabel('Exited')
plt.show()

# %%
# Countplot of a categorical variable
plt.figure(figsize=(8, 6))
# Get the count of each category and sort them in ascending order
order = df['Driving_experience'].value_counts().index
sns.countplot(x=df['Driving_experience'], palette="Set1", order=order)
plt.title('')
plt.xlabel('Driving_experience')
plt.ylabel('Exited')
plt.show()

# %%
# Countplot of a categorical variable
plt.figure(figsize=(8, 6))
# Get the count of each category and sort them in ascending order
order = df['Road_surface_conditions'].value_counts().index
sns.countplot(x=df['Road_surface_conditions'], palette="Set1", order=order)
plt.title('')
plt.xlabel('Road_surface_conditions')
plt.ylabel('Exited')
plt.show()

# %% [markdown]
# ## Pre Processing

# %% [markdown]
# ### Dealing with Missing Values

# %%
# This will display rows with at least one null value across all columns
rows_with_null = df[df.isnull().any(axis=1)]
rows_with_null
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12308  17:10:00      Friday              18-30          Male
# 12309   9:05:00      Friday              31-50        Female
# 12310   9:05:00      Friday              18-30          Male
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
# This will display all duplicate rows (excluding the first occurrence)
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Time, Day_of_week, Age_band_of_driver, Sex_of_driver, Educational_level, Vehicle_driver_relation, Driving_experience, Type_of_vehicle, Owner_of_vehicle, Service_year_of_vehicle, Defect_of_vehicle, Area_accident_occured, Lanes_or_Medians, Road_allignment, Types_of_Junction, Road_surface_type, Road_surface_conditions, Light_conditions, Weather_conditions, Type_of_collision, Number_of_vehicles_involved, Number_of_casualties, Vehicle_movement, Casualty_class, Sex_of_casualty, Age_band_of_casualty, Casualty_severity, Work_of_casuality, Fitness_of_casuality, Pedestrian_movement, Cause_of_accident, Accident_severity]
# Index: []
#
# [0 rows x 32 columns]

# %%
# Remove Duplicate Rows, ifany
# Keep first row and remove other duplicate rows of that row
df = df.drop_duplicates(keep='first')
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %% [markdown]
# ## Droping unwanted columns

# %%
# Remove unimportant cols: MSRP, Invoice
df.drop(['Vehicle_driver_relation'],axis=1, inplace=True)
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Driving_experience      Type_of_vehicle Owner_of_vehicle  \
# 0              1-2yr           Automobile            Owner
# 1         Above 10yr  Public (> 45 seats)            Owner
# 2              1-2yr      Lorry (41?100Q)            Owner
# 3             5-10yr  Public (> 45 seats)     Governmental
# 4              2-5yr                  NaN            Owner
#
#   Service_year_of_vehicle Defect_of_vehicle  ... Vehicle_movement  \
# 0              Above 10yr         No defect  ...   Going straight
# ...

# %%
df.drop(['Day_of_week'],axis=1, inplace=True)
df.head()
# Out:
#        Time Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00              18-30          Male   Above high school
# 1  17:02:00              31-50          Male  Junior high school
# 2  17:02:00              18-30          Male  Junior high school
# 3   1:06:00              18-30          Male  Junior high school
# 4   1:06:00              18-30          Male  Junior high school
#
#   Driving_experience      Type_of_vehicle Owner_of_vehicle  \
# 0              1-2yr           Automobile            Owner
# 1         Above 10yr  Public (> 45 seats)            Owner
# 2              1-2yr      Lorry (41?100Q)            Owner
# 3             5-10yr  Public (> 45 seats)     Governmental
# 4              2-5yr                  NaN            Owner
#
#   Service_year_of_vehicle Defect_of_vehicle Area_accident_occured  ...  \
# 0              Above 10yr         No defect     Residential areas  ...
# 1                 5-10yrs         No defect          Office areas  ...
# ...

# %% [markdown]
# ## Encoding Techniques

# %% [markdown]
# ## Transforming Categorical Columns

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to the "Gender" column
df['Casualty_class'] = label_encoder.fit_transform(df['Casualty_class'])

# Display the DataFrame with encoded "Gender"
print("DataFrame with encoded 'Casualty_class' column:")
print(df.head())
# Out:
# DataFrame with encoded 'Casualty_class' column:
#        Time Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00              18-30          Male   Above high school
# 1  17:02:00              31-50          Male  Junior high school
# 2  17:02:00              18-30          Male  Junior high school
# 3   1:06:00              18-30          Male  Junior high school
# 4   1:06:00              18-30          Male  Junior high school
#
#   Driving_experience      Type_of_vehicle Owner_of_vehicle  \
# 0              1-2yr           Automobile            Owner
# 1         Above 10yr  Public (> 45 seats)            Owner
# 2              1-2yr      Lorry (41?100Q)            Owner
# 3             5-10yr  Public (> 45 seats)     Governmental
# 4              2-5yr                  NaN            Owner
#
#   Service_year_of_vehicle Defect_of_vehicle Area_accident_occured  ...  \
# 0              Above 10yr         No defect     Residential areas  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

df['Sex_of_driver'] = label_encoder.fit_transform(df['Sex_of_driver'])

print("DataFrame with encoded 'Sex_of_driver' column:")
print(df.head())
# Out:
# DataFrame with encoded 'Sex_of_driver' column:
#        Time Age_band_of_driver  Sex_of_driver   Educational_level  \
# 0  17:02:00              18-30              1   Above high school
# 1  17:02:00              31-50              1  Junior high school
# 2  17:02:00              18-30              1  Junior high school
# 3   1:06:00              18-30              1  Junior high school
# 4   1:06:00              18-30              1  Junior high school
#
#   Driving_experience      Type_of_vehicle Owner_of_vehicle  \
# 0              1-2yr           Automobile            Owner
# 1         Above 10yr  Public (> 45 seats)            Owner
# 2              1-2yr      Lorry (41?100Q)            Owner
# 3             5-10yr  Public (> 45 seats)     Governmental
# 4              2-5yr                  NaN            Owner
#
#   Service_year_of_vehicle Defect_of_vehicle Area_accident_occured  ...  \
# 0              Above 10yr         No defect     Residential areas  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to the "Gender" column
df['Accident_severity'] = label_encoder.fit_transform(df['Accident_severity'])

# Display the DataFrame with encoded "Gender"
print("DataFrame with encoded 'Accident_severity' column:")
print(df.head())
# Out:
# DataFrame with encoded 'Accident_severity' column:
#        Time Age_band_of_driver  Sex_of_driver   Educational_level  \
# 0  17:02:00              18-30              1   Above high school
# 1  17:02:00              31-50              1  Junior high school
# 2  17:02:00              18-30              1  Junior high school
# 3   1:06:00              18-30              1  Junior high school
# 4   1:06:00              18-30              1  Junior high school
#
#   Driving_experience      Type_of_vehicle Owner_of_vehicle  \
# 0              1-2yr           Automobile            Owner
# 1         Above 10yr  Public (> 45 seats)            Owner
# 2              1-2yr      Lorry (41?100Q)            Owner
# 3             5-10yr  Public (> 45 seats)     Governmental
# 4              2-5yr                  NaN            Owner
#
#   Service_year_of_vehicle Defect_of_vehicle Area_accident_occured  ...  \
# 0              Above 10yr         No defect     Residential areas  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to the "Gender" column
df['Type_of_collision'] = label_encoder.fit_transform(df['Type_of_collision'])

# Display the DataFrame with encoded "Gender"
print("DataFrame with encoded 'Type_of_collision' column:")
print(df.head())
# Out:
# DataFrame with encoded 'Type_of_collision' column:
#        Time Age_band_of_driver  Sex_of_driver   Educational_level  \
# 0  17:02:00              18-30              1   Above high school
# 1  17:02:00              31-50              1  Junior high school
# 2  17:02:00              18-30              1  Junior high school
# 3   1:06:00              18-30              1  Junior high school
# 4   1:06:00              18-30              1  Junior high school
#
#   Driving_experience      Type_of_vehicle Owner_of_vehicle  \
# 0              1-2yr           Automobile            Owner
# 1         Above 10yr  Public (> 45 seats)            Owner
# 2              1-2yr      Lorry (41?100Q)            Owner
# 3             5-10yr  Public (> 45 seats)     Governmental
# 4              2-5yr                  NaN            Owner
#
#   Service_year_of_vehicle Defect_of_vehicle Area_accident_occured  ...  \
# 0              Above 10yr         No defect     Residential areas  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to the "Gender" column
df['Cause_of_accident'] = label_encoder.fit_transform(df['Cause_of_accident'])

# Display the DataFrame with encoded "Gender"
print("DataFrame with encoded 'Cause_of_accident' column:")
print(df.head())
# Out:
# DataFrame with encoded 'Cause_of_accident' column:
#        Time Age_band_of_driver  Sex_of_driver   Educational_level  \
# 0  17:02:00              18-30              1   Above high school
# 1  17:02:00              31-50              1  Junior high school
# 2  17:02:00              18-30              1  Junior high school
# 3   1:06:00              18-30              1  Junior high school
# 4   1:06:00              18-30              1  Junior high school
#
#   Driving_experience      Type_of_vehicle Owner_of_vehicle  \
# 0              1-2yr           Automobile            Owner
# 1         Above 10yr  Public (> 45 seats)            Owner
# 2              1-2yr      Lorry (41?100Q)            Owner
# 3             5-10yr  Public (> 45 seats)     Governmental
# 4              2-5yr                  NaN            Owner
#
#   Service_year_of_vehicle Defect_of_vehicle Area_accident_occured  ...  \
# 0              Above 10yr         No defect     Residential areas  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to the "Gender" column
df['Type_of_vehicle'] = label_encoder.fit_transform(df['Type_of_vehicle'])

# Display the DataFrame with encoded "Gender"
print("DataFrame with encoded 'Type_of_vehicle' column:")
print(df.head())
# Out:
# DataFrame with encoded 'Type_of_vehicle' column:
#        Time Age_band_of_driver  Sex_of_driver   Educational_level  \
# 0  17:02:00              18-30              1   Above high school
# 1  17:02:00              31-50              1  Junior high school
# 2  17:02:00              18-30              1  Junior high school
# 3   1:06:00              18-30              1  Junior high school
# 4   1:06:00              18-30              1  Junior high school
#
#   Driving_experience  Type_of_vehicle Owner_of_vehicle  \
# 0              1-2yr                0            Owner
# 1         Above 10yr               11            Owner
# 2              1-2yr                5            Owner
# 3             5-10yr               11     Governmental
# 4              2-5yr               17            Owner
#
#   Service_year_of_vehicle Defect_of_vehicle Area_accident_occured  ...  \
# 0              Above 10yr         No defect     Residential areas  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to the "Geography" column
df['Casualty_severity'] = label_encoder.fit_transform(df['Casualty_severity'])

# Display the DataFrame with encoded "Geography"
print("DataFrame with encoded 'Casualty_severity' column:")
print(df.head())
# Out:
# DataFrame with encoded 'Casualty_severity' column:
#        Time Age_band_of_driver  Sex_of_driver   Educational_level  \
# 0  17:02:00              18-30              1   Above high school
# 1  17:02:00              31-50              1  Junior high school
# 2  17:02:00              18-30              1  Junior high school
# 3   1:06:00              18-30              1  Junior high school
# 4   1:06:00              18-30              1  Junior high school
#
#   Driving_experience  Type_of_vehicle Owner_of_vehicle  \
# 0              1-2yr                0            Owner
# 1         Above 10yr               11            Owner
# 2              1-2yr                5            Owner
# 3             5-10yr               11     Governmental
# 4              2-5yr               17            Owner
#
#   Service_year_of_vehicle Defect_of_vehicle Area_accident_occured  ...  \
# 0              Above 10yr         No defect     Residential areas  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to the "Card type" column
df['Driving_experience_encoded'] = label_encoder.fit_transform(df['Driving_experience'])

# Display the DataFrame with encoded "Card type"
print("DataFrame with encoded 'Driving_experience' column:")
print(df.head())
# Out:
# DataFrame with encoded 'Driving_experience' column:
#        Time Age_band_of_driver  Sex_of_driver   Educational_level  \
# 0  17:02:00              18-30              1   Above high school
# 1  17:02:00              31-50              1  Junior high school
# 2  17:02:00              18-30              1  Junior high school
# 3   1:06:00              18-30              1  Junior high school
# 4   1:06:00              18-30              1  Junior high school
#
#   Driving_experience  Type_of_vehicle Owner_of_vehicle  \
# 0              1-2yr                0            Owner
# 1         Above 10yr               11            Owner
# 2              1-2yr                5            Owner
# 3             5-10yr               11     Governmental
# 4              2-5yr               17            Owner
#
#   Service_year_of_vehicle Defect_of_vehicle Area_accident_occured  ...  \
# 0              Above 10yr         No defect     Residential areas  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to the "Card type" column
df['Road_surface_conditions'] = label_encoder.fit_transform(df['Road_surface_conditions'])

# Display the DataFrame with encoded "Card type"
print("DataFrame with encoded 'Road_surface_conditions' column:")
print(df.head())
# Out:
# DataFrame with encoded 'Road_surface_conditions' column:
#        Time Age_band_of_driver  Sex_of_driver   Educational_level  \
# 0  17:02:00              18-30              1   Above high school
# 1  17:02:00              31-50              1  Junior high school
# 2  17:02:00              18-30              1  Junior high school
# 3   1:06:00              18-30              1  Junior high school
# 4   1:06:00              18-30              1  Junior high school
#
#   Driving_experience  Type_of_vehicle Owner_of_vehicle  \
# 0              1-2yr                0            Owner
# 1         Above 10yr               11            Owner
# 2              1-2yr                5            Owner
# 3             5-10yr               11     Governmental
# 4              2-5yr               17            Owner
#
#   Service_year_of_vehicle Defect_of_vehicle Area_accident_occured  ...  \
# 0              Above 10yr         No defect     Residential areas  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to the "Card type" column
df['Types_of_Junction'] = label_encoder.fit_transform(df['Types_of_Junction'])

# Display the DataFrame with encoded "Card type"
print("DataFrame with encoded 'Types_of_Junction' column:")
print(df.head())
# Out:
# DataFrame with encoded 'Types_of_Junction' column:
#        Time Age_band_of_driver  Sex_of_driver   Educational_level  \
# 0  17:02:00              18-30              1   Above high school
# 1  17:02:00              31-50              1  Junior high school
# 2  17:02:00              18-30              1  Junior high school
# 3   1:06:00              18-30              1  Junior high school
# 4   1:06:00              18-30              1  Junior high school
#
#   Driving_experience  Type_of_vehicle Owner_of_vehicle  \
# 0              1-2yr                0            Owner
# 1         Above 10yr               11            Owner
# 2              1-2yr                5            Owner
# 3             5-10yr               11     Governmental
# 4              2-5yr               17            Owner
#
#   Service_year_of_vehicle Defect_of_vehicle Area_accident_occured  ...  \
# 0              Above 10yr         No defect     Residential areas  ...
# ...

# %% [markdown]
# ### Scaling the numerical columns

# %%
from sklearn.preprocessing import MinMaxScaler

# Extract the column to be scaled
column_to_scale = df['Number_of_vehicles_involved']

# Reshape the column into a 2D array
reshaped_column = column_to_scale.values.reshape(-1, 1)

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Apply Min-Max scaling to the column
scaled_column = scaler.fit_transform(reshaped_column)

# Replace the original column with the scaled values
df['Number_of_vehicles_involved'] = scaled_column

# Display the DataFrame after scaling
print("DataFrame after scaling 'Number_of_vehicles_involved' with MinMaxScaler:")
print(df.head())
# Out:
# DataFrame after scaling 'Number_of_vehicles_involved' with MinMaxScaler:
#        Time Age_band_of_driver  Sex_of_driver   Educational_level  \
# 0  17:02:00              18-30              1   Above high school
# 1  17:02:00              31-50              1  Junior high school
# 2  17:02:00              18-30              1  Junior high school
# 3   1:06:00              18-30              1  Junior high school
# 4   1:06:00              18-30              1  Junior high school
#
#   Driving_experience  Type_of_vehicle Owner_of_vehicle  \
# 0              1-2yr                0            Owner
# 1         Above 10yr               11            Owner
# 2              1-2yr                5            Owner
# 3             5-10yr               11     Governmental
# 4              2-5yr               17            Owner
#
#   Service_year_of_vehicle Defect_of_vehicle Area_accident_occured  ...  \
# 0              Above 10yr         No defect     Residential areas  ...
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Extract the column to be scaled
column_to_scale = df['Number_of_casualties']

# Reshape the column into a 2D array
reshaped_column = column_to_scale.values.reshape(-1, 1)

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Apply Min-Max scaling to the column
scaled_column = scaler.fit_transform(reshaped_column)

# Replace the original column with the scaled values
df['Number_of_casualties'] = scaled_column

# Display the DataFrame after scaling
print("DataFrame after scaling 'Number_of_casualties' with MinMaxScaler:")
print(df.head())
# Out:
# DataFrame after scaling 'Number_of_casualties' with MinMaxScaler:
#        Time Age_band_of_driver  Sex_of_driver   Educational_level  \
# 0  17:02:00              18-30              1   Above high school
# 1  17:02:00              31-50              1  Junior high school
# 2  17:02:00              18-30              1  Junior high school
# 3   1:06:00              18-30              1  Junior high school
# 4   1:06:00              18-30              1  Junior high school
#
#   Driving_experience  Type_of_vehicle Owner_of_vehicle  \
# 0              1-2yr                0            Owner
# 1         Above 10yr               11            Owner
# 2              1-2yr                5            Owner
# 3             5-10yr               11     Governmental
# 4              2-5yr               17            Owner
#
#   Service_year_of_vehicle Defect_of_vehicle Area_accident_occured  ...  \
# 0              Above 10yr         No defect     Residential areas  ...
# ...

# %%
data_types = df.dtypes

# Separate numerical and categorical columns
numerical_columns = data_types[data_types != 'object'].index.tolist()
categorical_columns = data_types[data_types == 'object'].index.tolist()

print("Numerical columns:", numerical_columns)
print("\nCategorical columns:", categorical_columns)
# Out:
# Numerical columns: ['Sex_of_driver', 'Type_of_vehicle', 'Types_of_Junction', 'Road_surface_conditions', 'Type_of_collision', 'Number_of_vehicles_involved', 'Number_of_casualties', 'Casualty_class', 'Casualty_severity', 'Cause_of_accident', 'Accident_severity', 'Driving_experience_encoded']
#
# Categorical columns: ['Time', 'Age_band_of_driver', 'Educational_level', 'Driving_experience', 'Owner_of_vehicle', 'Service_year_of_vehicle', 'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment', 'Road_surface_type', 'Light_conditions', 'Weather_conditions', 'Vehicle_movement', 'Sex_of_casualty', 'Age_band_of_casualty', 'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement']

# %%
df.columns
# Out:
# Index(['Time', 'Age_band_of_driver', 'Sex_of_driver', 'Educational_level',
#        'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle',
#        'Service_year_of_vehicle', 'Defect_of_vehicle', 'Area_accident_occured',
#        'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction',
#        'Road_surface_type', 'Road_surface_conditions', 'Light_conditions',
#        'Weather_conditions', 'Type_of_collision',
#        'Number_of_vehicles_involved', 'Number_of_casualties',
#        'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty',
#        'Age_band_of_casualty', 'Casualty_severity', 'Work_of_casuality',
#        'Fitness_of_casuality', 'Pedestrian_movement', 'Cause_of_accident',
#        'Accident_severity', 'Driving_experience_encoded'],
#       dtype='object')

# %%
# Remove unimportant cols: MSRP, Invoice
df.drop(['Time', 'Age_band_of_driver', 'Educational_level', 'Driving_experience', 'Owner_of_vehicle', 'Service_year_of_vehicle', 'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment', 'Road_surface_type', 'Light_conditions', 'Weather_conditions', 'Vehicle_movement', 'Sex_of_casualty', 'Age_band_of_casualty', 'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement'],axis=1, inplace=True)
df.head()
# Out:
#    Sex_of_driver  Type_of_vehicle  Types_of_Junction  Road_surface_conditions  \
# 0              1                0                  1                        0
# 1              1               11                  1                        0
# 2              1                5                  1                        0
# 3              1               11                  7                        0
# 4              1               17                  7                        0
#
#    Type_of_collision  Number_of_vehicles_involved  Number_of_casualties  \
# 0                  3                     0.166667              0.142857
# 1                  8                     0.166667              0.142857
# 2                  2                     0.166667              0.142857
# 3                  8                     0.166667              0.142857
# 4                  8                     0.166667              0.142857
#
# ...

# %%
df.columns
# Out:
# Index(['Sex_of_driver', 'Type_of_vehicle', 'Types_of_Junction',
#        'Road_surface_conditions', 'Type_of_collision',
#        'Number_of_vehicles_involved', 'Number_of_casualties', 'Casualty_class',
#        'Casualty_severity', 'Cause_of_accident', 'Accident_severity',
#        'Driving_experience_encoded'],
#       dtype='object')

# %% [markdown]
# ## Visualisation

# %%
#Scatterplot using matplot library
plt.scatter(df['Number_of_casualties'],df['Number_of_vehicles_involved'])
plt.colorbar(label='Exited')
plt.title('Scatter plot of Number_of_casualties vs Number_of_vehicles_involved')
plt.xlabel('Number_of_casualties')
plt.ylabel('Number_of_vehicles_involved')
plt.show()

# %%
#Lineplot using matplot library
plt.plot(df['Number_of_vehicles_involved'])
plt.plot(df['Number_of_casualties'])
plt.title('Lineplot')
plt.xlabel('Number_of_vehicles_involved')
plt.ylabel('Number_of_casualties')
plt.show()

# %%
#Scatterplot using seaborn library
sns.scatterplot(x='Number_of_casualties',y='Number_of_vehicles_involved',data=df)
plt.title('Scatter plot of Number_of_casualties vs Number_of_vehicles_involved')
plt.xlabel('Number_of_casualties')
plt.ylabel('Number_of_vehicles_involved')
plt.show()

# %%
#Lineplot using Seaborn library
sns.lineplot(x='Cause_of_accident',y='Accident_severity',data=df)
plt.title('Line plot of Cause_of_accident vs Accident_severity')
plt.show()

# %%
# Calculate correlation matrix
correlation_matrix = df.corr()
# Heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Sort correlations for 'Exited' column in descending order
sorted_corr_Exited = correlation_matrix['Number_of_casualties'].sort_values(ascending=False)
sorted_corr_Exited
# Out:
# Number_of_casualties           1.000000
# Number_of_vehicles_involved    0.213427
# Road_surface_conditions        0.072828
# Sex_of_driver                  0.048503
# Type_of_vehicle                0.006822
# Casualty_severity             -0.009643
# Driving_experience_encoded    -0.010072
# Casualty_class                -0.012820
# Cause_of_accident             -0.022096
# Type_of_collision             -0.023269
# Types_of_Junction             -0.042272
# Accident_severity             -0.045339
# Name: Number_of_casualties, dtype: float64

# %% [markdown]
# ### <span style='color:blue'>Apply Machine Learning Algorithm</span>

# %% [markdown]
# ### Selecting X and Y variables

# %%
x = df[['Sex_of_driver', 'Type_of_vehicle', 'Types_of_Junction', 'Road_surface_conditions', 'Type_of_collision', 'Casualty_class', 'Casualty_severity', 'Cause_of_accident', 'Driving_experience_encoded']]

x
# Out:
#        Sex_of_driver  Type_of_vehicle  Types_of_Junction  \
# 0                  1                0                  1
# 1                  1               11                  1
# 2                  1                5                  1
# 3                  1               11                  7
# 4                  1               17                  7
# ...              ...              ...                ...
# 12311              1                4                  1
# 12312              1                0                  1
# 12313              1                1                  1
# 12314              0                5                  1
# 12315              1                7                  2
#
#        Road_surface_conditions  Type_of_collision  Casualty_class  \
# 0                            0                  3               3
# 1                            0                  8               3
# 2                            0                  2               0
# ...

# %%
# Select only numeric type of columns by their names as:
y = df[['Accident_severity']]
y
# Out:
#        Accident_severity
# 0                      2
# 1                      2
# 2                      1
# 3                      2
# 4                      2
# ...                  ...
# 12311                  2
# 12312                  2
# 12313                  1
# 12314                  2
# 12315                  2
#
# [12316 rows x 1 columns]

# %% [markdown]
# ### Create and Fit Model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.feature_selection import SelectKBest, chi2
k_best = 10
selector = SelectKBest(chi2, k=k_best)
X_train_selected = selector.fit_transform(X_train, y_train)
X_test_selected = selector.transform(X_test)
selected_indices = selector.get_support(indices=True)
selected_features = X_train.columns[selected_indices]

import numpy as np

# Assuming X_train is a DataFrame
original_feature_names = np.array(['Sex_of_driver','Type_of_vehicle', 'Types_of_Junction', 'Road_surface_conditions', 'Type_of_collision','Casualty_class', 'Casualty_severity', 'Cause_of_accident', 'Accident_severity', 'Driving_experience_encoded'])

# Manually select 9 features
selected_features = original_feature_names[:10]
# Out:
# C:\Users\Amulya\anaconda3\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=10 is greater than n_features=9. All the features will be returned.
#   warnings.warn(

# %%
print(selected_features)
# Out:
# ['Sex_of_driver' 'Type_of_vehicle' 'Types_of_Junction'
#  'Road_surface_conditions' 'Type_of_collision' 'Casualty_class'
#  'Casualty_severity' 'Cause_of_accident' 'Accident_severity'
#  'Driving_experience_encoded']

# %% [markdown]
# ## <span style='color:blue'>Evaluate Model</span>

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import SelectKBest, chi2

# Assuming X_train and y_train are your training data
# Assuming k_best is the number of features to select

# Create a SelectKBest object
selector = SelectKBest(chi2, k=k_best)

# Fit the selector to your training data
X_train_selected = selector.fit_transform(X_train, y_train)

# Create a DecisionTreeClassifier object
dtr = DecisionTreeClassifier(random_state=42)

# Now you can use X_train_selected for training your model
dtr.fit(X_train_selected, y_train)
# Out:
# C:\Users\Amulya\anaconda3\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=10 is greater than n_features=9. All the features will be returned.
#   warnings.warn(
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
dtr=DecisionTreeClassifier(random_state=42)
dtr.fit(X_train_selected,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred=dtr.predict(X_test_selected)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7069805194805194

# %%
import pickle
import numpy as np

# Assuming X_train is a DataFrame
original_feature_names = np.array(['Sex_of_driver','Type_of_vehicle', 'Types_of_Junction', 'Road_surface_conditions', 'Type_of_collision','Casualty_class', 'Casualty_severity', 'Cause_of_accident','Accident_severity', 'Driving_experience_encoded'])

# Manually select 9 features
selected_features = original_feature_names[:9]

# Save selected feature names to a pickle file
with open('features.pkl', 'wb') as file:
    pickle.dump(selected_features, file)

print("Selected feature names saved to 'selected_features.pkl' successfully.")
# Out:
# Selected feature names saved to 'selected_features.pkl' successfully.

# %%
 #Import necessary libraries
import pickle
from sklearn.tree import DecisionTreeClassifier

# Assuming X_train_selected and y_train are defined
# and used for training the model
# Define and train the model
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train_selected, y_train)

# Save the trained model
with open("features.pkl", "wb") as file:
    pickle.dump(model, file)

# %%
import pickle
pickle.dump(model, open("features.pkl", "wb"))

# %%
import pickle

# Load the model from the file
model = pickle.load(open("features.pkl", "rb"))

# %%
import pickle
import numpy as np
from sklearn.preprocessing import OneHotEncoder

# Assuming these are your feature values, replace them with actual values
Sex_of_driver = 1
Type_of_vehicle = 0
Type_of_collision = 3
Casualty_class = 3
Casualty_severity = 3
Cause_of_accident = 9
Driving_experience_encoded = 0
Road_surface_conditions = 0
Types_of_Junction = 1

# Prepare the input features as a 2D array
features = np.array([[Sex_of_driver, Type_of_vehicle, Types_of_Junction, Road_surface_conditions, Type_of_collision, Casualty_class, Casualty_severity, Cause_of_accident, Driving_experience_encoded]])

# Create a OneHotEncoder object
encoder = OneHotEncoder()

# Fit and transform the input features
features_encoded = encoder.fit_transform(features).toarray()

# Load the trained model
model = pickle.load(open("features.pkl", "rb"))

# Make predictions using the encoded features
y_pred_proba = model.predict_proba(features_encoded)[:, 1]  # Probability of class 1
threshold = 0.5  # Set your threshold here

# Apply threshold to convert probabilities to binary predictions
y_pred_binary = (y_pred_proba > threshold).astype(int)

print(f"Predicted value: {y_pred_binary[0]}")
# Out:
# Predicted value: 0
